# %%
# basic Python notebook

# variables and print
my_name = "toto"
print ("let's talk about", my_name)


# concatenate : +
s1 = "toto"
s2 = "tutu"
print (s1+s2)

#
# READING FILES
#
from sys import argv
filename ="test.data"
print ("we're going to read ", filename)
#target = open (filename, "r")
#target.close()


#
# FUNCTIONS
#
def print_two(*args) :
    arg1, arg2 = args
    print ("arg1 :",arg1," arg2 : ", arg2)
    
def print_two_again(arg1, arg2) :
    print ("arg1 :",arg1," arg2 : ", arg2)

print_two ("toto", "tutu")
print_two_again ("tata", "titi")

def addition(a, b) :
    print ("adding ",a," and ",b)
    return a+b

addition(3, 2)

#
# LOGIC
#
"test" == "test"
"test" == "testing"

#
# STATEMENT
#
people = 20
cats = 12
if people<cats:
    print ("Too many cats")
if people > cats :
    print ("Too many people")

#
# LOOPS AND LISTS
#
the_count = [1, 2, 3, 4, 5]
fruits =["apples", "oranges", "pears", "apricots"]
change = [1, "pennies", 2, "dimes", 3, "quarter"]

# first kind of for-loop
for number in the_count :
    print ("this is count ", number)


elements = []
for i in range (0,6):
    print ("adding ",i," to the list")
    elements.append(i)
for i in elements:
    print("element was :", i)
    
#
# DOING STUFF WITH LISTS
#
animals = ['bear', 'tiger', 'penguin', 'zebra']
bear = animals[0]

ten_things = "Apples Oranges Crows Telephone Light Sugar"
stuff = ten_things.split(' ')
print (stuff)


#
# DICTIONARIES
#
stuff = {'name': 'Zed', 'age': 39, 'height': 6 * 12 + 2}
print (stuff["name"])


#
# MODULES, CLASSES AND OBJECTS

#
# Out:
# let's talk about toto
# tototutu
# we're going to read  test.data
# arg1 : toto  arg2 :  tutu
# arg1 : tata  arg2 :  titi
# adding  3  and  2
# Too many people
# this is count  1
# this is count  2
# this is count  3
# this is count  4
# this is count  5
# adding  0  to the list
# adding  1  to the list
# adding  2  to the list
# adding  3  to the list
# adding  4  to the list
# adding  5  to the list
# element was : 0
# element was : 1
# element was : 2
# element was : 3
# element was : 4
# element was : 5
# ['Apples', 'Oranges', 'Crows', 'Telephone', 'Light', 'Sugar']
# Zed
